# %%
a = 100 
b = 200
c = 300 
print(a , b , c)

# %%
# sep là phân cách giữ hai đối tượng
print("Hello Huỳnh Hậu", "C++", "Java", sep="--")

# %%
# print (object, sep = seperator, end = end)
print('Huỳnh Hậu')
